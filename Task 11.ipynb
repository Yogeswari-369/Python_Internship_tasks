# %%
# 2.	Install pandas package (try to import the package in a python file


import pandas as pd
print("Installed Successfully")
# Out:
# Installed Successfully

# %%
# 3.	Import a module that picks random number and write a program to fetch a random number from 1 to  100 on every run

import random
r=random.randint(1,100)
print(r)
# Out:
# 51

# %%
r=random.randint(1,100)
print(r)
# Out:
# 70

# %%
# 4.	Import sys package and find the python path

import sys
sys.path
# Out:
# ['/home/jovyan/demo',
#  '/srv/conda/envs/notebook/lib/python37.zip',
#  '/srv/conda/envs/notebook/lib/python3.7',
#  '/srv/conda/envs/notebook/lib/python3.7/lib-dynload',
#  '',
#  '/srv/conda/envs/notebook/lib/python3.7/site-packages',
#  '/srv/conda/envs/notebook/lib/python3.7/site-packages/locket-0.2.1-py3.7.egg',
#  '/srv/conda/envs/notebook/lib/python3.7/site-packages/IPython/extensions',
#  '/home/jovyan/.ipython']
